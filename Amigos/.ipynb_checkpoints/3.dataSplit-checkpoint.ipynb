# %%
import os
import glob
from sklearn import preprocessing
import sklearn as skl
from collections import defaultdict
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
from sklearn.model_selection import train_test_split
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
# Read processed data
df = pd.read_pickle(r'D:\CIC\Combined\Filtered 40 least\cic_ids_2018_data.pkl')

# %%
# Here, you need to divide given columns into two types of variables dependent (or target variable) and independent variable (or feature variables)

# Drop the target value from independent variables
X = df.drop(["Label"], axis=1)

# Get just the target values
y = df["Label"]

print(f"X: {X.shape}")
print(f"y: {y.shape}")
print(f"Orginal: {df.shape}")
# Out:
# X: (16137242, 39)
# y: (16137242,)
# Orginal: (16137242, 40)

# %%
# 70% training and 30% test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
print(f"Train Size X = {len(X_train)} | Test Size X = {len(X_test)} | Test is {len(X_test)/len(df)}% of Train")

print(f"Train Size y = {len(y_train)} | Test Size y = {len(y_test)} | Test is {len(y_test)/len(df)}% of Train")
# Out:
# Train Size X = 11296069 | Test Size X = 4841173 | Test is 0.30000002478738313% of Train
# Train Size y = 11296069 | Test Size y = 4841173 | Test is 0.30000002478738313% of Train

# %%
# The following shows the number of Benign (0) vs Malicous (1) entries
# This allows us to check if the data is uniformaly distributed
print('Training data benign vs malicious:')
print(y_train.value_counts())

train_attack_types = y_train.value_counts()
train_attack_types.plot(kind='barh', figsize=(20,10), fontsize=20)
# Out:
# Training data benign vs malicious:
# 0    9373579
# 1    1922490
# Name: Label, dtype: int64

# %%
# The following shows the number of Benign (0) vs Malicous (1) entries
# This allows us to check if the data is uniformaly distributed
print('Test data benign vs malicious:')
print(y_test.value_counts())

train_attack_types = y_test.value_counts()
train_attack_types.plot(kind='barh', figsize=(20,10), fontsize=20)
# Out:
# Test data benign vs malicious:
# 0    4016670
# 1     824503
# Name: Label, dtype: int64

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11296069 entries, 2794206 to 318661
# Data columns (total 39 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Protocol           float64
#  1   Timestamp          float64
#  2   Tot Fwd Pkts       float64
#  3   TotLen Bwd Pkts    float64
#  4   Fwd Pkt Len Min    float64
#  5   Fwd Pkt Len Std    float64
#  6   Bwd Pkt Len Max    float64
#  7   Bwd Pkt Len Min    float64
#  8   Bwd Pkt Len Mean   float64
#  9   Bwd Pkt Len Std    float64
#  10  Bwd IAT Max        float64
#  11  Bwd IAT Min        float64
#  12  Fwd PSH Flags      float64
#  13  Bwd PSH Flags      float64
#  14  Fwd URG Flags      float64
#  15  Bwd URG Flags      float64
#  16  Pkt Len Min        float64
#  17  Pkt Len Mean       float64
#  18  FIN Flag Cnt       float64
#  19  SYN Flag Cnt       float64
#  20  URG Flag Cnt       float64
#  21  CWE Flag Count     float64
#  22  ECE Flag Cnt       float64
#  23  Bwd Seg Size Avg   float64
#  24  Fwd Byts/b Avg     float64
#  25  Fwd Pkts/b Avg     float64
#  26  Fwd Blk Rate Avg   float64
#  27  Bwd Byts/b Avg     float64
#  28  Bwd Pkts/b Avg     float64
#  29  Bwd Blk Rate Avg   float64
#  30  Subflow Bwd Pkts   float64
#  31  Fwd Act Data Pkts  float64
#  32  Active Mean        float64
#  33  Active Std         float64
#  34  Active Max         float64
#  35  Active Min         float64
#  36  Idle Mean          float64
#  37  Idle Std           float64
#  38  Idle Max           float64
# dtypes: float64(39)
# memory usage: 3.4 GB

# %%
# Create test and train files containing raw data
X_train.to_pickle(r'D:\CIC\Train and Test\Remove40LeastSig\X_train.pkl')
X_test.to_pickle(r'D:\CIC\Train and Test\Remove40LeastSig\X_test.pkl')

# Create test and train files containing target values
y_test.to_pickle(r'D:\CIC\Train and Test\Remove40LeastSig\y_test.pkl')
y_train.to_pickle(r'D:\CIC\Train and Test\Remove40LeastSig\y_train.pkl')
