# %%
import glob
import pandas as pd
import utils
from sklearn import preprocessing
import numpy as np

# %%
# Read processed data
df = pd.read_pickle(r'D:\CIC\Combined\Complete\cic_ids_2018_data.pkl')

# %%
# These are the 40 least significant columns according to Decision Tree Algorithm
remove_dt_columns = [
    "Active Max",       "Active Mean",      "Active Min",       "Active Std", 
    "Bwd Blk Rate Avg", "Bwd Byts/b Avg",   "Bwd PSH Flags",    "Bwd Pkt Len Min", 
    "Bwd Pkt Len Std",  "Bwd Pkts/b Avg",   "Bwd URG Flags",    "CWE Flag Count", 
    "Down/Up Ratio",    "ECE Flag Cnt",     "Fwd Blk Rate Avg", "Fwd Byts/b Avg", 
    "Fwd PSH Flags",    "Fwd Pkt Len Min",  "Fwd Pkt Len Std",  "Fwd Pkts/b Avg", 
    "Fwd Seg Size Avg", "Fwd URG Flags",    "Idle Std",         "Pkt Len Max", 
    "Pkt Len Mean",     "Pkt Len Min",      "Pkt Len Std",      "Pkt Len Var", 
    "Pkt Size Avg",     "Protocol",         "RST Flag Cnt",     "SYN Flag Cnt", 
    "Subflow Bwd Byts", "Subflow Bwd Pkts", "Subflow Fwd Byts", 
    "Timestamp",        "Tot Bwd Pkts",     "Tot Fwd Pkts",     "TotLen Bwd Pkts"
]

# These are the 40 least signiciant columns according to Random Forest Alogirhtm
remove_rf_columns = [
    "ACK Flag Cnt", "Bwd Header Len", "Bwd IAT Mean", "Bwd IAT Std", 
    "Bwd IAT Tot", "Bwd Pkts/s", "Down/Up Ratio", "Dst Port", 
    "Flow Byts/s", "Flow Duration", "Flow IAT Max", "Flow IAT Mean", 
    "Flow IAT Min", "Flow IAT Std", "Flow Pkts/s", "Fwd Header Len", 
    "Fwd IAT Max", "Fwd IAT Mean", "Fwd IAT Min", "Fwd IAT Std", 
    "Fwd IAT Tot", "Fwd Pkt Len Max", "Fwd Pkt Len Mean", "Fwd Pkts/s", 
    "Fwd Seg Size Avg", "Fwd Seg Size Min", "Idle Min", "Init Bwd Win Byts", 
    "Init Fwd Win Byts", "PSH Flag Cnt", "Pkt Len Max", "Pkt Len Std", 
    "Pkt Len Var", "Pkt Size Avg", "RST Flag Cnt", "Subflow Bwd Byts", 
    "Subflow Fwd Byts", "Subflow Fwd Pkts", "Tot Bwd Pkts", "TotLen Fwd Pkts"
]

# %%
print('Before removing: ', df.shape)
print(df.info())

# Although 'Subflow Fwd Byts' was ranked a low with feature importance
# It was worked with value 0.356747 for entropy gain so we will leave it in the dataset

df = df.drop(remove_dt_columns, axis=1)

print('After removing: ', df.shape)
print(df.info())
# Out:
# Before removing:  (16137242, 80)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16137242 entries, 0 to 613103
# Data columns (total 80 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Dst Port           float64
#  1   Protocol           float64
#  2   Timestamp          float64
#  3   Flow Duration      float64
#  4   Tot Fwd Pkts       float64
#  5   Tot Bwd Pkts       float64
#  6   TotLen Fwd Pkts    float64
#  7   TotLen Bwd Pkts    float64
#  8   Fwd Pkt Len Max    float64
#  9   Fwd Pkt Len Min    float64
#  10  Fwd Pkt Len Mean   float64
#  11  Fwd Pkt Len Std    float64
#  12  Bwd Pkt Len Max    float64
#  13  Bwd Pkt Len Min    float64
#  14  Bwd Pkt Len Mean   float64
#  15  Bwd Pkt Len Std    float64
#  16  Flow Byts/s        float64
#  17  Flow Pkts/s        float64
#  18  Flow IAT Mean      float64
#  19  Flow IAT Std       float64
#  20  Flow IAT Max       float64
#  21  Flow IAT Min       float64
#  22  Fwd IAT Tot        float64
#  23  Fwd IAT Mean       float64
#  24  Fwd IAT Std        float64
#  25  Fwd IAT Max        float64
#  26  Fwd IAT Min        float64
#  27  Bwd IAT Tot        float64
#  28  Bwd IAT Mean       float64
#  29  Bwd IAT Std        float64
#  30  Bwd IAT Max        float64
#  31  Bwd IAT Min        float64
#  32  Fwd PSH Flags      float64
#  33  Bwd PSH Flags      float64
#  34  Fwd URG Flags      float64
#  35  Bwd URG Flags      float64
#  36  Fwd Header Len     float64
#  37  Bwd Header Len     float64
#  38  Fwd Pkts/s         float64
#  39  Bwd Pkts/s         float64
#  40  Pkt Len Min        float64
#  41  Pkt Len Max        float64
#  42  Pkt Len Mean       float64
#  43  Pkt Len Std        float64
#  44  Pkt Len Var        float64
#  45  FIN Flag Cnt       float64
#  46  SYN Flag Cnt       float64
#  47  RST Flag Cnt       float64
#  48  PSH Flag Cnt       float64
#  49  ACK Flag Cnt       float64
#  50  URG Flag Cnt       float64
#  51  CWE Flag Count     float64
#  52  ECE Flag Cnt       float64
#  53  Down/Up Ratio      float64
#  54  Pkt Size Avg       float64
#  55  Fwd Seg Size Avg   float64
#  56  Bwd Seg Size Avg   float64
#  57  Fwd Byts/b Avg     float64
#  58  Fwd Pkts/b Avg     float64
#  59  Fwd Blk Rate Avg   float64
#  60  Bwd Byts/b Avg     float64
#  61  Bwd Pkts/b Avg     float64
#  62  Bwd Blk Rate Avg   float64
#  63  Subflow Fwd Pkts   float64
#  64  Subflow Fwd Byts   float64
#  65  Subflow Bwd Pkts   float64
#  66  Subflow Bwd Byts   float64
#  67  Init Fwd Win Byts  float64
#  68  Init Bwd Win Byts  float64
#  69  Fwd Act Data Pkts  float64
#  70  Fwd Seg Size Min   float64
#  71  Active Mean        float64
#  72  Active Std         float64
#  73  Active Max         float64
#  74  Active Min         float64
#  75  Idle Mean          float64
#  76  Idle Std           float64
#  77  Idle Max           float64
#  78  Idle Min           float64
#  79  Label              int32
# dtypes: float64(79), int32(1)
# memory usage: 9.7 GB
# None
# After removing:  (16137242, 41)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16137242 entries, 0 to 613103
# Data columns (total 41 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Dst Port           float64
#  1   Flow Duration      float64
#  2   TotLen Fwd Pkts    float64
#  3   Fwd Pkt Len Max    float64
#  4   Fwd Pkt Len Mean   float64
#  5   Bwd Pkt Len Max    float64
#  6   Bwd Pkt Len Mean   float64
#  7   Flow Byts/s        float64
#  8   Flow Pkts/s        float64
#  9   Flow IAT Mean      float64
#  10  Flow IAT Std       float64
#  11  Flow IAT Max       float64
#  12  Flow IAT Min       float64
#  13  Fwd IAT Tot        float64
#  14  Fwd IAT Mean       float64
#  15  Fwd IAT Std        float64
#  16  Fwd IAT Max        float64
#  17  Fwd IAT Min        float64
#  18  Bwd IAT Tot        float64
#  19  Bwd IAT Mean       float64
#  20  Bwd IAT Std        float64
#  21  Bwd IAT Max        float64
#  22  Bwd IAT Min        float64
#  23  Fwd Header Len     float64
#  24  Bwd Header Len     float64
#  25  Fwd Pkts/s         float64
#  26  Bwd Pkts/s         float64
#  27  FIN Flag Cnt       float64
#  28  PSH Flag Cnt       float64
#  29  ACK Flag Cnt       float64
#  30  URG Flag Cnt       float64
#  31  Bwd Seg Size Avg   float64
#  32  Subflow Fwd Pkts   float64
#  33  Init Fwd Win Byts  float64
#  34  Init Bwd Win Byts  float64
#  35  Fwd Act Data Pkts  float64
#  36  Fwd Seg Size Min   float64
#  37  Idle Mean          float64
#  38  Idle Max           float64
#  39  Idle Min           float64
#  40  Label              int32
# dtypes: float64(40), int32(1)
# memory usage: 5.0 GB
# None

# %%
df.to_pickle(r'D:\CIC\Combined\Filtered 40 least - DT\cic_ids_2018_data.pkl')
