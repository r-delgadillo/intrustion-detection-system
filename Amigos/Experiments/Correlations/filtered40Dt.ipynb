# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_file_path = r'D:\CIC\Combined\Filtered 40 - DT\cic_ids_2018_data.pkl'

df = pd.read_pickle(data_file_path)

# %%
corr = df.corr()

# %%
plt.matshow(corr)
plt.show()

# %%
f = plt.figure(figsize=(40, 20))
plt.matshow(corr, fignum=f.number)
plt.xticks(range(df.shape[1]), df.columns, fontsize=14, rotation=70)
plt.yticks(range(df.shape[1]), df.columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
# plt.title('Correlation Matrix', fontsize=16)

# %%
map = corr.style.background_gradient(cmap='coolwarm').set_precision(3)
map
# Out:
# <style  type="text/css" >
#     #T_31df0a02_8afb_11ea_80ae_5cf3708e53cdrow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_31df0a02_8afb_11ea_80ae_5cf3708e53cdrow0_col1 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }    #T_31df0a02_8afb_11ea_80ae_5cf3708e53cdrow0_col2 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_31df0a02_8afb_11ea_80ae_5cf3708e53cdrow0_col3 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_31df0a02_8afb_11ea_80ae_5cf3708e53cdrow0_col4 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_31df0a02_8afb_11ea_80ae_5cf3708e53cdrow0_col5 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_31df0a02_8afb_11ea_80ae_5cf3708e53cdrow0_col6 {
#             background-color:  #6f92f3;
#             color:  #000000;
# ...

# %%
map.to_excel("Filtered 40 Dt.xlsx", sheet_name='Filtered 40 DT')
