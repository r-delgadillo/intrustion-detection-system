# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_file_path = r'D:\CIC\Combined\Filtered 40 - RF\cic_ids_2018_data.pkl'

df = pd.read_pickle(data_file_path)

# %%
corr = df.corr()

# %%
plt.matshow(corr)
plt.show()

# %%
f = plt.figure(figsize=(40, 20))
plt.matshow(corr, fignum=f.number)
plt.xticks(range(df.shape[1]), df.columns, fontsize=14, rotation=70)
plt.yticks(range(df.shape[1]), df.columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
# plt.title('Correlation Matrix', fontsize=16)

# %%
map = corr.style.background_gradient(cmap='coolwarm').set_precision(3)
map
# Out:
# C:\Users\rodelga\Anaconda3\lib\site-packages\matplotlib\colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# C:\Users\rodelga\Anaconda3\lib\site-packages\pandas\io\formats\style.py:1089: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(s.to_numpy()) if vmin is None else vmin
# C:\Users\rodelga\Anaconda3\lib\site-packages\pandas\io\formats\style.py:1090: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(s.to_numpy()) if vmax is None else vmax
# <style  type="text/css" >
#     #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow0_col2 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow0_col4 {
#             background-color:  #ec8165;
#             color:  #000000;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow0_col7 {
#             background-color:  #da5a49;
#             color:  #000000;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow0_col8 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow0_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow0_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow0_col11 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow0_col12 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow0_col13 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow0_col14 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow0_col15 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow0_col16 {
#             background-color:  #e36b54;
#             color:  #000000;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow0_col17 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow0_col18 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow0_col19 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow0_col20 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow0_col21 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow0_col22 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow0_col23 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow0_col24 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow0_col25 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow0_col26 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow0_col27 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow0_col28 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow0_col29 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow0_col30 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow0_col31 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow0_col32 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow0_col33 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow0_col34 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow0_col35 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow0_col36 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow0_col37 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow0_col38 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow0_col39 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow1_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow1_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow1_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow1_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow1_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow1_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow1_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow1_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow1_col11 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow1_col12 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow1_col13 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow1_col14 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow1_col15 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow1_col16 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow1_col17 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow1_col18 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9bca2cc_8afc_11ea_8fd7_5cf3708e53cdrow1_col19 {
#             background-color:  #

# %%
map.to_excel("Filtered 40 RF.xlsx", sheet_name='Filtered 40 RF')
